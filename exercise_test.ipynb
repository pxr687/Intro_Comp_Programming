# %%
# RUN THIS CELL - DO NOT CHANGE THE CODE.
import mark_exercise_1

# %% [markdown]
# # Exercise 1

# %% [markdown]
# # Question 1

# %%
answer_1 = 100

# %%
# MARK EXERCISE 1
mark_exercise_1.check_answer_1(dir())

# %% [markdown]
# # Question 2

# %%
def answer_2(a):
    return a * 2

# %%
# MARK EXERCISE 2
mark_exercise_1.check_answer_2(answer_2)

# %%
mark_exercise_1.mark_all(answer_1, answer_2)
