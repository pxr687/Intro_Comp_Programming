# %%
# A number.
42
# Out:
# 42

# %%
# Some text.
"Bang Wa has a BTS and MRT station."
# Out:
# 'Bang Wa has a BTS and MRT station.'

# %%
# The `print()` function.
print('This is the print function, it is printing some text!')
# Out:
# This is the print function, it is printing some text!

# %%
# The `print()` function with a number.
print(100)
# Out:
# 100

# %%
# The `print()` function (again).
print("This is a very long input, which as some text and the number", 100)
# Out:
# This is a very long input, which as some text and the number 100

# %%
# The `print()` function (again, this time with a variable).
number_variable = 3765
print("This is a very long input, which as some text and another number, which is", number_variable)
# Out:
# This is a very long input, which as some text and another number, which is 3765

# %%
# A number, multiplied by 10.
10 * 10
# Out:
# 100

# %%
# Text, multiplied by 10.
"This is text!" * 10
# Out:
# 'This is text!This is text!This is text!This is text!This is text!This is text!This is text!This is text!This is text!This is text!'

# %%
# Cost of 10 months.
1235 * 10
# Out:
# 12350

# %%
"1,235" * 10
# Out:
# '1,2351,2351,2351,2351,2351,2351,2351,2351,2351,235'

# %%
# Use `round()` to remove a decimal place.
round(4.2)
# Out:
# 4

# %%
# `round()` again
round(10.9)
# Out:
# 11

# %%
# Use `round()` with some text.
round("This is some text.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Use `round()` with some text.
# ----> 2 round("This is some text.")
#
# TypeError: type str doesn't define __round__ method

# %%
# Use `type()` with some text.
type("This is some text.")
# Out:
# str

# %%
# Use `type()` with a number.
type(1)
# Out:
# int

# %%
# `type()` with a different number.
type(4.2)
# Out:
# float

# %%
# Assign a numeric variable.
my_number = 10

# %%
# Show the value of `my_number`.
my_number
# Out:
# 10

# %%
# Show the `type()` of the variable.
type(my_number)
# Out:
# int

# %%
# Assign another numeric variable.
my_other_number = 10.0

# %%
# Show the value of `my_other_number`.
my_other_number
# Out:
# 10.0

# %%
# Show the `type()` of `my_other_number`.
type(my_other_number)
# Out:
# float

# %%
# Create a variable containing an `int`.
my_int = 10

# Show the value of `my_int`
my_int
# Out:
# 10

# %%
# Show the `type()` of `my_int`.
type(my_int)
# Out:
# int

# %%
# Change `my_int` to a `float`.
float(my_int)
# Out:
# 10.0

# %%
# Store our `float` in a variable.
my_float = float(my_int)

# Show the value of `my_float`.
my_float
# Out:
# 10.0

# %%
# Show the `type()` of `my_float`.
type(my_float)
# Out:
# float

# %%
int(my_float)
# Out:
# 10

# %%
2/2
# Out:
# 1.0

# %%
type(2/2)
# Out:
# float

# %%
# Change `my_float` to `str`.
my_string = str(my_float)

# Show the value of `my_string`.
my_string
# Out:
# '10.0'

# %%
# Show the `type()` of `my_string`.
type(my_string)
# Out:
# str

# %%
# Should be a number, but it is text.
salary = "1,235"

# %%
# Ouch!
salary * 10
# Out:
# '1,2351,2351,2351,2351,2351,2351,2351,2351,2351,235'

# %%
# Ouch! (again).
int(salary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Ouch! (again).
# ----> 2 int(salary)
#
# ValueError: invalid literal for int() with base 10: '1,235'

# %%
# Re-assign the variable, with no ",".
salary = "1235"

# Show the value of `salary`.
salary
# Out:
# '1235'

# %%
int(salary)
# Out:
# 1235

# %%
salary_as_int = int(salary)
type(salary_as_int)
# Out:
# int

# %%
# Calculate the salary over 10 months.
salary_as_int * 10
# Out:
# 12350

# %%
# Your code here
name = ...

# Show the value of `name`.
name
# Out:
# Ellipsis

# %%
# Your code here
name = ...

# Show the value of `name`.
name
# Out:
# Ellipsis

# %%
eight_seven_nine = "879"

# Show the value of `eight_seven_nine`.
eight_seven_nine
# Out:
# '879'

# %%
# DO NOT CHANGE THIS CODE, JUST RUN THE CELL.
from jupyprint import jupyprint
assert type(eight_seven_nine) == int, f"Ouch, that's not right, `eight_seven_nine` should be the `int` data type. Right now it is `{type(eight_seven_nine)}`."
jupyprint("*That is **correct**! Well done!*")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[43], line 3
#       1 # DO NOT CHANGE THIS CODE, JUST RUN THE CELL.
#       2 from jupyprint import jupyprint
# ----> 3 assert type(eight_seven_nine) == int, f"Ouch, that's not right, `eight_seven_nine` should be the `int` data type. Right now it is `{type(eight_seven_nine)}`."
#       4 jupyprint("*That is **correct**! Well done!*")
#
# AssertionError: Ouch, that's not right, `eight_seven_nine` should be the `int` data type. Right now it is `<class 'str'>`.

# %%
number_of_visitors = 118

ticket_price = "250"

total_ticket_revenue = number_of_visitors * ticket_price

# Show the value of `total_ticket_revenue`.
total_ticket_revenue
# Out:
# ''

# %%
# DO NOT CHANGE THIS CODE, JUST RUN THE CELL.
assert type(total_ticket_revenue) == float , f"Ouch, that's not right, `total_ticket_revenue` should be the `float` data type. Right now it is `{type(total_ticket_revenue)}`."
assert total_ticket_revenue == 29500.0,  f"Ouch, that's not right, `total_ticket_revenue` is the wrong value, it should be 29500.0, but right now it is `{total_ticket_revenue}`."
jupyprint("*That is **correct**! Well done!*")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 # DO NOT CHANGE THIS CODE, JUST RUN THE CELL.
# ----> 2 assert type(total_ticket_revenue) == float , f"Ouch, that's not right, `total_ticket_revenue` should be the `float` data type. Right now it is `{type(total_ticket_revenue)}`."
#       3 assert total_ticket_revenue == 29500.0,  f"Ouch, that's not right, `total_ticket_revenue` is the wrong value, it should be 29500.0, but right now it is `{total_ticket_revenue}`."
#       4 jupyprint("*That is **correct**! Well done!*")
#
# AssertionError: Ouch, that's not right, `total_ticket_revenue` should be the `float` data type. Right now it is `<class 'str'>`.

# %%
number_of_monitor_lizards = 435

number_of_cats = 121

# Add the variables together in the messagee.
how_many_cats_monitors_message = "There are number_of_cats+number_of_monitor_lizards cats and monitor lizards in Lumpini park."

# Show the message.
print(how_many_cats_monitors_message)
# Out:
# There are number_of_cats+number_of_monitor_lizards cats and monitor lizards in Lumpini park.

# %%
# DO NOT CHANGE THIS CODE, JUST RUN THE CELL.
assert type(how_many_cats_monitors_message) == str , f"Ouch, that's not right, `how_many_cats_monitors_message` should be the `str` data type. Right now it is `{type(how_many_cats_monitors_message)}`."
assert how_many_cats_monitors_message == "There are 556 cats and monitor lizards in Lumpini park.",  f"Ouch, that's not right, `how_many_cats_monitors_message` is the wrong value, it should be:\n `'There are 556 cats and monitor lizards in Lumpini park.'`\n ...but right now it is:\n `'{how_many_cats_monitors_message}'`."
jupyprint("*That is **correct**! Well done!*")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[47], line 3
#       1 # DO NOT CHANGE THIS CODE, JUST RUN THE CELL.
#       2 assert type(how_many_cats_monitors_message) == str , f"Ouch, that's not right, `how_many_cats_monitors_message` should be the `str` data type. Right now it is `{type(how_many_cats_monitors_message)}`."
# ----> 3 assert how_many_cats_monitors_message == "There are 556 cats and monitor lizards in Lumpini park.",  f"Ouch, that's not right, `how_many_cats_monitors_message` is the wrong value, it should be:\n `'There are 556 cats and monitor lizards in Lumpini park.'`\n ...but right now it is:\n `'{how_many_cats_monitors_message}'`."
#       4 jupyprint("*That is **correct**! Well done!*")
#
# AssertionError: Ouch, that's not right, `how_many_cats_monitors_message` is the wrong value, it should be:
# ...

# %%
nine_nine_nine_as_words = "nine_nine_nine"

# DO NOT CHANGE THE LINE OF CODE BELOW THIS.
nine_nine_nine_as_number = float(nine_nine_nine_as_words)

# Show the value of `nine_nine_nine_as_number`.
nine_nine_nine_as_number
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 4
#       1 nine_nine_nine_as_words = "nine_nine_nine"
#       2
#       3 # DO NOT CHANGE THE LINE OF CODE BELOW THIS.
# ----> 4 nine_nine_nine_as_number = float(nine_nine_nine_as_words)
#       5
#       6 # Show the value of `nine_nine_nine_as_number`.
#       7 nine_nine_nine_as_number
#
# ValueError: could not convert string to float: 'nine_nine_nine'

# %%
# DO NOT CHANGE THIS CODE, JUST RUN THE CELL.
assert type(nine_nine_nine_as_number) == float, f"Ouch, that's not right, `nine_nine_nine_as_number` should be the `float` data type. Right now it is `{type(nine_nine_nine_as_number)}`."
assert nine_nine_nine_as_number == 999.0, f"Ouch, that's not right, `nine_nine_nine_as_number` is the wrong value, it should be 999.0, but right now it is `{nine_nine_nine_as_number}`."
jupyprint("*That is **correct**! Well done!*")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 # DO NOT CHANGE THIS CODE, JUST RUN THE CELL.
# ----> 2 assert type(nine_nine_nine_as_number) == float, f"Ouch, that's not right, `nine_nine_nine_as_number` should be the `float` data type. Right now it is `{type(nine_nine_nine_as_number)}`."
#       3 assert nine_nine_nine_as_number == 999.0, f"Ouch, that's not right, `nine_nine_nine_as_number` is the wrong value, it should be 999.0, but right now it is `{nine_nine_nine_as_number}`."
#       4 jupyprint("*That is **correct**! Well done!*")
#
# NameError: name 'nine_nine_nine_as_number' is not defined
