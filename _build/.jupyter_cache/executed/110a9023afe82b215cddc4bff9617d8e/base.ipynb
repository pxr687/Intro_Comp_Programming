# %%
3 > 1
# Out:
# True

# %%
type(3 > 1)
# Out:
# bool

# %%
3 > 1 + 1
# Out:
# True

# %%
4 < 5
# Out:
# True

# %%
4 < 3
# Out:
# False

# %%
4 <= 4
# Out:
# True

# %%
a = 4

# %%
a == 4
# Out:
# True

# %%
"Dog" > "Catastrophe"
# Out:
# True

# %%
"Catastrophe" > "Cat"
# Out:
# True
