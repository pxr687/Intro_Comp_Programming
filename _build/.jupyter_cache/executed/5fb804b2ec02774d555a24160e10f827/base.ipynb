# %%
# RUN THIS CELL - DO NOT CHANGE THE CODE.
import numpy as np
import mark_exercise_2a
# answer_1, answer_2, answer_3, answer_4, answer_5, answer_6, answer_7, answer_8, answer_9 = mark_exercise_2a.pre_define_blanks(5)

# %%
# Type your answer below.
answer_1 = ...

# %%
# DO NOT CHANGE THIS CODE.
# RUN THIS CELL TO MARK YOUR ANSWER.
mark_exercise_2a.check_answer_1(answer_1)
# Out:
# *Question 1 is not correct! `answer_1`  should be `'a'`, `'b'`or `'c'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 1 is not correct! `answer_1` is the wrong answer.*

# %%
# Type your answer below.
answer_2 = ...

# %%
# DO NOT CHANGE THIS CODE.
# RUN THIS CELL TO MARK YOUR ANSWER.
mark_exercise_2a.check_answer_2(answer_2)
# Out:
# *Question 2 is not correct! `answer_2`  should be `'a'`, `'b'`or `'c'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 2 is not correct! `answer_2` is the wrong answer.*

# %%
# Type your answer below.
answer_3 = ...

# %%
# DO NOT CHANGE THIS CODE.
# RUN THIS CELL TO MARK YOUR ANSWER.
mark_exercise_2a.check_answer_3(answer_3)
# Out:
# *Question 3 is not correct! `answer_3`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 3 is not correct! `answer_3` is the wrong answer.*

# %%
# Type your answer below.
answer_4 = ...

# %%
# DO NOT CHANGE THIS CODE.
# RUN THIS CELL TO MARK YOUR ANSWER.
mark_exercise_2a.check_answer_4(answer_4)
# Out:
# *Question 4 is not correct! `answer_4`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 4 is not correct! `answer_4` is the wrong answer.*

# %%
# Type your answer below.
answer_5 = ...

# %%
# DO NOT CHANGE THIS CODE.
# RUN THIS CELL TO MARK YOUR ANSWER.
mark_exercise_2a.check_answer_5(answer_5)
# Out:
# *Question 5 is not correct! `answer_5`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 5 is not correct! `answer_5` is the wrong answer.*

# %%
# Type your answer below.
answer_6 = ...

# %%
# DO NOT CHANGE THIS CODE.
# RUN THIS CELL TO MARK YOUR ANSWER.
mark_exercise_2a.check_answer_6(answer_6)
# Out:
# *Question 6 is not correct! `answer_6`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 6 is not correct! `answer_6` is the wrong answer.*

# %%
# Type your answer below.
answer_7 = ...

# %%
# DO NOT CHANGE THIS CODE.
# RUN THIS CELL TO MARK YOUR ANSWER.
mark_exercise_2a.check_answer_7(answer_7)
# Out:
# *Question 7 is not correct! `answer_7`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 7 is not correct! `answer_7` is the wrong answer.*

# %%
# Type your answer below.
answer_8 = ...

# %%
# DO NOT CHANGE THIS CODE.
# RUN THIS CELL TO MARK YOUR ANSWER.
mark_exercise_2a.check_answer_8(answer_8)
# Out:
# *Question 8 is not correct! `answer_8`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 8 is not correct! `answer_8` is the wrong answer.*

# %%
# Type your answer below.
answer_9 = ...

# %%
# DO NOT CHANGE THIS CODE.
# RUN THIS CELL TO MARK YOUR ANSWER.
mark_exercise_2a.check_answer_9(answer_9)
# Out:
# *Question 9 is not correct! `answer_9`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 9 is not correct! `answer_9` is the wrong answer.*

# %%
# DO NOT CHANGE THIS CELL. 
# Run this cell to mark all of your answers.
mark_exercise_2a.mark_all(answer_1, 
                         answer_2, 
                         answer_3,
                         answer_4,
                         answer_5,
                         answer_6,
                         answer_7,
                         answer_8,
                         answer_9)
# Out:
# *Question 1 is not correct! `answer_1`  should be `'a'`, `'b'`or `'c'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 1 is not correct! `answer_1` is the wrong answer.*
# *Question 2 is not correct! `answer_2`  should be `'a'`, `'b'`or `'c'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 2 is not correct! `answer_2` is the wrong answer.*
# *Question 3 is not correct! `answer_3`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 3 is not correct! `answer_3` is the wrong answer.*
# *Question 4 is not correct! `answer_4`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 4 is not correct! `answer_4` is the wrong answer.*
# *Question 5 is not correct! `answer_5`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 5 is not correct! `answer_5` is the wrong answer.*
# *Question 6 is not correct! `answer_6`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 6 is not correct! `answer_6` is the wrong answer.*
# *Question 7 is not correct! `answer_7`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 7 is not correct! `answer_7` is the wrong answer.*
# *Question 8 is not correct! `answer_8`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 8 is not correct! `answer_8` is the wrong answer.*
# *Question 9 is not correct! `answer_9`  should be `'a'`, `'b'`, `'c'` or `'d'`. Make sure you did not forget to use quotation marks! `'`*
# *Question 9 is not correct! `answer_9` is the wrong answer.*
# # You got 0/9 marks.
