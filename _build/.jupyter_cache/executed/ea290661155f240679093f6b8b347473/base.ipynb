# %%
import numpy as np

# %%
"e" in "Peter"
# Out:
# True

# %%
"z" in "Peter"
# Out:
# False

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
(10 > 8) and (9 < 11)
# Out:
# True

# %%
(10 > 8) and (9 < 8)
# Out:
# False

# %%
(10 > 8) or (9 < 11)
# Out:
# True
