# %%
"loud".upper()
# Out:
# 'LOUD'

# %%
'hitchhiker'.replace('hi', 'ma')
# Out:
# 'matchmaker'

# %%
s = "train"
t = s.replace('t', 'ing')
u = t.replace('in', 'de')
u
# Out:
# 'degrade'

# %%
s
# Out:
# 'train'
