# %%
"loud".upper()
# Out:
# 'LOUD'

# %%
'hitchhiker'.replace('hi', 'ma')
# Out:
# 'matchmaker'

# %%
s = "train"
t = s.replace('t', 'ing')
u = t.replace('in', 'de')
u
# Out:
# 'degrade'

# %%
# The string we start with.
s
# Out:
# 'train'

# %%
# Replace "t" with "ing".
t = s.replace('t', 'ing')
t
# Out:
# 'ingrain'

# %%
# Replace "in" with "de"
u = t.replace('in', 'de')
u
# Out:
# 'degrade'

# %%
s
# Out:
# 'train'

# %%
answer_1 = "Intr0duction to Camapar Programming"

# Show the value of `answer_1`.
answer_1
# Out:
# 'Intr0duction to Camapar Programming'

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(answer_1, "Introduction to Computer Programming")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Introduction to Computer Programming'`!*

# %%
pres_title = "presentotion of climate change"

# Show the value.
pres_title
# Out:
# 'presentotion of climate change'

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(pres_title, "Presentation on Climate Change")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Presentation on Climate Change'`!*

# %%
answer  = ""

# Show the value.
answer
# Out:
# ''

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(pres_title, "Presentation on Climate Change")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Presentation on Climate Change'`!*

# %%
answer  = ""

# Show the value.
answer
# Out:
# ''

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(pres_title, "Presentation on Climate Change")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Presentation on Climate Change'`!*

# %%
answer  = ""

# Show the value.
answer
# Out:
# ''

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(pres_title, "Presentation on Climate Change")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Presentation on Climate Change'`!*

# %%
answer  = ""

# Show the value.
answer
# Out:
# ''

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(pres_title, "Presentation on Climate Change")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Presentation on Climate Change'`!*

# %%
answer  = ""

# Show the value.
answer
# Out:
# ''

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(pres_title, "Presentation on Climate Change")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Presentation on Climate Change'`!*

# %%
answer  = ""

# Show the value.
answer
# Out:
# ''

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(pres_title, "Presentation on Climate Change")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Presentation on Climate Change'`!*

# %%
answer  = ""

# Show the value.
answer
# Out:
# ''

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(pres_title, "Presentation on Climate Change")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Presentation on Climate Change'`!*

# %%
answer  = ""

# Show the value.
answer
# Out:
# ''

# %%
# DO NOT CHANGE THIS CODE!
from mark_string_methods_page import check_answer
check_answer(pres_title, "Presentation on Climate Change")
# Out:
# *Your answer to Your answer to Question 1 is **NOT CORRECT!** `answer_1` should be `'Presentation on Climate Change'`!*
