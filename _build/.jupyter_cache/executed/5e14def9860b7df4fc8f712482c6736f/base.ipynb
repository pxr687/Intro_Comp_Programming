# %%
"loud".upper()
# Out:
# 'LOUD'

# %%
'hitchhiker'.replace('hi', 'ma')
# Out:
# 'matchmaker'

# %%
s = "train"
t = s.replace('t', 'ing')
u = t.replace('in', 'de')
u
# Out:
# 'degrade'

# %%
# The string we start with.
s
# Out:
# 'train'

# %%
# Replace "t" with "ing".
t = s.replace('t', 'ing')
t
# Out:
# 'ingrain'

# %%
# Replace "in" with "de"
u = t.replace('in', 'de')
u
# Out:
# 'degrade'

# %%
s
# Out:
# 'train'
