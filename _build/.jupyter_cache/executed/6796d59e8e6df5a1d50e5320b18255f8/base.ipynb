# %%
"data" + "science"
# Out:
# 'datascience'

# %%
"data" + " " + "science"
# Out:
# 'data science'

# %%
"This won't work with a single-quoted string!"
# Out:
# "This won't work with a single-quoted string!"

# %%
"That's " + str(1 + 1) + ' ' + str(True)
# Out:
# "That's 2 True"
