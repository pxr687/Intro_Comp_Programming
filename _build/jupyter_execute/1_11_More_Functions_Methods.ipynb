# %% [markdown]
# # More on Functions (and Methods)
#
# This page builds on (import) statements, collections and functions.
#
# [Recap of what we have learned so far]
#
# ## More on Functions

# %%
import numpy as np

# %%
ages_of_class = [20, 22, 22, 23, 21, 17, 21, 15, 21, 16, 24, 24, 19, 22, 21]

ages_of_class
# Out:
# [20, 22, 22, 23, 21, 17, 21, 15, 21, 16, 24, 24, 19, 22, 21]

# %%
import matplotlib.pyplot as plt

plt.hist(ages_of_class)
plt.xlabel('Age (Years)')
plt.ylabel('Number of Students');

# %%
np.mean(ages_of_class)
# Out:
# np.float64(20.533333333333335)

# %%
print("The average age of students in the class is", np.mean(ages_of_class), "years old.")
# Out:
# The average age of students in the class is 20.533333333333335 years old.

# %% [markdown]
# Convert age in years to months?

# %%
ages_of_class * 12
# Out:
# [20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
#  15,
#  21,
#  16,
#  24,
#  24,
#  19,
#  22,
#  21,
#  20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
#  15,
#  21,
#  16,
#  24,
#  24,
#  19,
#  22,
#  21,
#  20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
#  15,
#  21,
#  16,
#  24,
#  24,
#  19,
#  22,
#  21,
#  20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
#  15,
#  21,
#  16,
#  24,
#  24,
#  19,
#  22,
#  21,
#  20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
#  15,
#  21,
#  16,
#  24,
#  24,
#  19,
#  22,
#  21,
#  20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
#  15,
#  21,
#  16,
#  24,
#  24,
#  19,
#  22,
#  21,
#  20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
#  15,
#  21,
#  16,
#  24,
#  24,
#  19,
#  22,
#  21,
#  20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
#  15,
#  21,
#  16,
#  24,
#  24,
#  19,
#  22,
#  21,
#  20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
#  15,
#  21,
#  16,
#  24,
#  24,
#  19,
#  22,
#  21,
#  20,
#  22,
#  22,
#  23,
#  21,
#  17,
#  21,
# ...

# %%
len(ages_of_class * 12)
# Out:
# 180

# %%
180/12
# Out:
# 15.0

# %%
180/12 == len(ages_of_class)
# Out:
# True

# %%
ages_of_class_array = np.array(ages_of_class)

# %%
ages_of_class_array
# Out:
# array([20, 22, 22, 23, 21, 17, 21, 15, 21, 16, 24, 24, 19, 22, 21])

# %%
ages_of_class_array * 12
# Out:
# array([240, 264, 264, 276, 252, 204, 252, 180, 252, 192, 288, 288, 228,
#        264, 252])

# %%
ages_in_months = ages_of_class_array * 12

# %%
plt.hist(ages_in_months)
plt.xlabel('Age (Months) - Approximate')
plt.ylabel('Number of Students');

# %%
print("The average age of students in the class is", np.mean(ages_in_months), "months old.")
# Out:
# The average age of students in the class is 246.4 months old.

# %% [markdown]
# ## Methods
#
# Methods are like a different flavour of function...

# %%
ages_in_months.mean()
# Out:
# np.float64(246.4)

# %%
np.mean(ages_in_months)
# Out:
# np.float64(246.4)

# %%
type(ages_in_months)
# Out:
# numpy.ndarray

# %% [markdown]
# `dir(ages_in_months)` is messy but it will show you all the methods available on Numpy array...

# %%
ages_in_months.max()
# Out:
# np.int64(288)

# %%
np.max(ages_in_months)
# Out:
# np.int64(288)

# %%
ages_in_months.min()
# Out:
# np.int64(180)

# %%
np.min(ages_in_months)
# Out:
# np.int64(180)

# %% [markdown]
# ## String methods

# %%
my_name = "Pete"

my_name
# Out:
# 'Pete'

# %%
dir(my_name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# ## Exercise 5 - Functions and Methods
#
# *Remember*: your [assignments, tests and exams](https://pxr687.github.io/Intro_Comp_Programming/1_02_Class_Grades_Assignments_Exams.html) will also be a bit like this.
#
# Click [here 🚀](https://mybinder.org/v2/gh/pxr687/Intro_Comp_Programming/main?urlpath=tree/exercise_4_statements.ipynb) to launch the exercise.

# %% [markdown]
# ----------------------------------------------------------
#
# [🏡](intro.md).
