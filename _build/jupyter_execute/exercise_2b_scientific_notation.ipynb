# %% [markdown]
# # Exercise 2b
#
# If you need help, open the _[textbook page](https://pxr687.github.io//Intro_Comp_Programming/1_08_01_More_On_Numbers.html)_ for this exercise.
#
# ## Instructions
#
# This exercise works a bit differently to the others you have seen. **DO NOT** change the code in the cell below, just run it.
#
# This is what will happen:
#
# - you will be shown a number in scientific notation (e.g. `1e01`)
#
# - a box will appear, you should type the same number BUT NOT in scientific notation e.g. if your number is `1e01`, then you should type `10`.
#
# You will then get a message saying if your answer is correct:
#
# ![](https://raw.githubusercontent.com/pxr687/Intro_Comp_Programming/refs/heads/main/images/sci_not_exercise.gif)
#
# You will be asked 10 questions in total.
#
# Run the cell below to get started...
#
# *Note*: you can do the exercise again by stopping/interrupting/restarting your kernel, and re-running the cell.

# %%
# RUN THIS CELL - DO NOT CHANGE THE CODE.
from mk_sci_note_tester import test_me        
test_me()
# Out:
# ## Question 1
# Here is a number in scientific notation: 3.265150e+02
# Type this number WITHOUT scientific notation.
# *Note*: you must type a number, not text, or you will get an error.
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# Cell In[1], line 3
#       1 # RUN THIS CELL - DO NOT CHANGE THE CODE.
#       2 from mk_sci_note_tester import test_me
# ----> 3 test_me()
#
# File ~\Intro_Comp_Programming\mk_sci_note_tester.py:9, in test_me(n_iter)
#       7 for rep in np.arange(n_iter):
#       8     jupyprint(f'## Question {rep+1}')
# ----> 9     score_arr = mk_sci_note_tester()
#      10 jupyprint(f"## You got {int(score_arr.sum())} out of {n_iter} marks!")
#
# File ~\Intro_Comp_Programming\mk_sci_note_tester.py:20, in mk_sci_note_tester()
#      18 jupyprint("*Note*: you must type a number, not text, or you will get an error.")
#      19 sleep(1)
# ---> 20 usr_input = float(input())
#      21 if np.isclose(usr_input, random_big_or_small):
#      22     score_arr = np.append(score_arr, 1)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\kernelbase.py:1259, in Kernel.raw_input(self, prompt)
#    1257 if not self._allow_stdin:
#    1258     msg = "raw_input was called, but this frontend does not support input requests."
# -> 1259     raise StdinNotImplementedError(msg)
#    1260 return self._input_request(
#    1261     str(prompt),
#    1262     self._parent_ident["shell"],
#    1263     self.get_parent("shell"),
#    1264     password=False,
#    1265 )
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support input requests.

# %% [markdown]
# ## Go back to the textbook:
#
# Click _[here](https://pxr687.github.io/Intro_Comp_Programming/1_08_01_More_On_Numbers.html)_ to go back to the course textbook.
